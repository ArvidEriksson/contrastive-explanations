# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, title):

    x = np.arange(4)
    width = 0.07
    distance = 0.035
    
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()

    iter1acc_t_bar = ax2.bar(x-4*width-distance, iter1acc_t, width, color='#333333')
    iter1p_t_bar = ax2.bar(x-3*width-distance, iter1p_t, width, color='#878787')
    iter1y_t_bar = ax1.bar(x-2*width-distance, iter1y_t, width, color='#c0c0c0')

    iter2acc_t_bar = ax2.bar(x-width, iter2acc_t, width, color='#ff3333')
    iter2p_t_bar = ax2.bar(x, iter2p_t, width, color='#ffa333')
    iter2y_t_bar = ax1.bar(x+width, iter2y_t, width, color='#ffe4c4')

    iter10acc_t_bar = ax2.bar(x+2*width+distance, iter10acc_t, width, color='#3333ff')
    iter10p_t_bar = ax2.bar(x+3*width+distance, iter10p_t, width, color='#6787e7')
    iter10y_t_bar = ax1.bar(x+4*width+distance, iter10y_t, width, color='#b0c4de')

    #ax1.set_xticks(x, ['Weighted', 'Original', 'Mean', 'Max'])
    ax1.set_xticks(x)
    ax1.set_xticklabels(['Weighted', 'Original', 'Mean', 'Max'])
    
    ax1.set_ylabel('Changes over $y_t$ (one challow bar)')
    ax2.set_ylabel('Changes over $p_t$ and Accuracy (two dark bars)')
    
    fig.legend([iter1acc_t_bar, iter1p_t_bar, iter1y_t_bar,
                iter2acc_t_bar, iter2p_t_bar, iter2y_t_bar,
                iter10acc_t_bar, iter10p_t_bar, iter10y_t_bar],
               ["iteration 1, accuracy", "iteration 1, avg. $p_t$", "iteration 1, avg. $y_t$",
                "iteration 2, accuracy", "iteration 2, avg. $p_t$", "iteration 2, avg. $y_t$",
                "iteration 10, accuracy", "iteration 10, avg. $p_t$", "iteration 10, avg. $y_t$"],
               loc='upper center', bbox_to_anchor=(0.5, -0.07), fancybox=True, shadow=True, ncol=3)
    
    plt.title(title)
    plt.show()

# %% [markdown]
# # Results
#
# Model: MobileNetV3Small\
# $\epsilon=0.001$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.6766586429968406
accuracy_perturbed_normal_1 = 0.8540601023017903
accuracy_perturbed_max_1 = 0.8879076086956522
accuracy_perturbed_weighted_1 = 0.9152613491048593
accuracy_perturbed_mean_1 = 0.8540601023017903
accuracy_original_2 = 0.6768243662554536
accuracy_perturbed_normal_2 = 0.8662578042726041
accuracy_perturbed_max_2 = 0.9147512505641643
accuracy_perturbed_weighted_2 = 0.9325541597713254
accuracy_perturbed_mean_2 = 0.8662578042726041
accuracy_original_10 = 0.6768796073416579
accuracy_perturbed_normal_10 = 0.8742007672634271
accuracy_perturbed_max_10 = 0.9349824168797954
accuracy_perturbed_weighted_10 = 0.9416959718670077
accuracy_perturbed_mean_10 = 0.8742007672634271
yt_original_1 = 12.728992407279247
yt_perturbed_normal_1 = 17.40921838082316
yt_perturbed_max_1 = 15.118936858213772
yt_perturbed_weighted_1 = 15.984839332073241
yt_perturbed_mean_1 = 17.409218379603626
yt_original_2 = 12.731428468318851
yt_perturbed_normal_2 = 17.888541103324012
yt_perturbed_max_2 = 15.411883939562552
yt_perturbed_weighted_2 = 16.350767091716953
yt_perturbed_mean_2 = 17.88854110820214
yt_original_10 = 12.730420741888569
yt_perturbed_normal_10 = 18.226145529686033
yt_perturbed_max_10 = 15.582954425031266
yt_perturbed_weighted_10 = 16.614060232401503
yt_perturbed_mean_10 = 18.22614552236884
pt_original_1 = 0.5855514826753255
pt_perturbed_normal_1 = 0.7848329783400612
pt_perturbed_max_1 = 0.7941684320454707
pt_perturbed_weighted_1 = 0.8368460312676247
pt_perturbed_mean_1 = 0.784832978035178
pt_original_2 = 0.5857097713843636
pt_perturbed_normal_2 = 0.8002596096614437
pt_perturbed_max_2 = 0.8180879223377199
pt_perturbed_weighted_2 = 0.8602172026548849
pt_perturbed_mean_2 = 0.8002596100425476
pt_original_10 = 0.5857632424672852
pt_perturbed_normal_10 = 0.8106896106696799
pt_perturbed_max_10 = 0.8314104775333648
pt_perturbed_weighted_10 = 0.8739327702223493
pt_perturbed_mean_10 = 0.8106896094501476

iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "MobileNetV3Small")

# %% [markdown]
# # Results
#
# Model: MobileNetV3Small\
# $\epsilon=0.003$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.6766034019106364
accuracy_perturbed_normal_1 = 0.9216046712802768
accuracy_perturbed_max_1 = 0.9266950786068904
accuracy_perturbed_weighted_1 = 0.9652180965097037
accuracy_perturbed_mean_1 = 0.9216046712802768
accuracy_original_2 = 0.6764376786520234
accuracy_perturbed_normal_2 = 0.9500726361516474
accuracy_perturbed_max_2 = 0.9738697908831052
accuracy_perturbed_weighted_2 = 0.9914482097186701
accuracy_perturbed_mean_2 = 0.9500726361516474
accuracy_original_10 = 0.6766586429968406
accuracy_perturbed_normal_10 = 0.9658727621483376
accuracy_perturbed_max_10 = 0.9945252557544757
accuracy_perturbed_weighted_10 = 0.9976422634271099
accuracy_perturbed_mean_10 = 0.9658727621483376
yt_original_1 = 12.730104441533003
yt_perturbed_normal_1 = 20.544646509468098
yt_perturbed_max_1 = 16.174511061909865
yt_perturbed_weighted_1 = 17.80314563424386
yt_perturbed_mean_1 = 20.544646509468098
yt_original_2 = 12.727233829400728
yt_perturbed_normal_2 = 23.18380168270882
yt_perturbed_max_2 = 17.86797613378071
yt_perturbed_weighted_2 = 19.516582479257412
yt_perturbed_mean_2 = 23.183801670513496
yt_original_10 = 12.730354952995125
yt_perturbed_normal_10 = 25.695760297653315
yt_perturbed_max_10 = 19.2793574223433
yt_perturbed_weighted_10 = 20.959028485485966
yt_perturbed_mean_10 = 25.695758341523387
pt_original_1 = 0.5855521159937315
pt_perturbed_normal_1 = 0.8694089803549335
pt_perturbed_max_1 = 0.848546531270532
pt_perturbed_weighted_1 = 0.9116383011993545
pt_perturbed_mean_1 = 0.8694089801262712
pt_original_2 = 0.58544452941936
pt_perturbed_normal_2 = 0.9150156430576158
pt_perturbed_max_2 = 0.9188331867880224
pt_perturbed_weighted_2 = 0.965262791156159
pt_perturbed_mean_2 = 0.9150156432100575
pt_original_10 = 0.5856137247875218
pt_perturbed_normal_10 = 0.9395492859661122
pt_perturbed_max_10 = 0.9590021885569443
pt_perturbed_weighted_10 = 0.9870802699147588
pt_perturbed_mean_10 = 0.9395491860406783


iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "MobileNetV3Small")

# %% [markdown]
# # OLD

# %% [markdown]
# # Results
#
# Model: vgg16\
# $\epsilon=0.001$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.715593030690537
accuracy_perturbed_normal_1 = 0.8314617966751918
accuracy_perturbed_max_1 = 0.8970588235294118
accuracy_perturbed_weighted_1 = 0.9224744245524297
accuracy_perturbed_mean_1 = 0.8315617007672634

accuracy_original_2 = 0.7159526854219949
accuracy_perturbed_normal_2 = 0.83903452685422
accuracy_perturbed_max_2 = 0.9253316815856778
accuracy_perturbed_weighted_2 = 0.941156489769821
accuracy_perturbed_mean_2 = 0.838974584398977

accuracy_original_10 = 0.715712915601023
accuracy_perturbed_normal_10 = 0.8452885230179028
accuracy_perturbed_max_10 = 0.9454923273657289
accuracy_perturbed_weighted_10 = 0.9509071291560103
accuracy_perturbed_mean_10 = 0.844928868286445


yt_original_1 = 18.421731495186496
yt_perturbed_normal_1 = 27.552222066523168
yt_perturbed_max_1 = 22.603742009233635
yt_perturbed_weighted_1 = 23.6505240491589
yt_perturbed_mean_1 = 27.54625497022858

yt_original_2 = 18.42829524037783
yt_perturbed_normal_2 = 28.463419423993592
yt_perturbed_max_2 = 23.330632175630925
yt_perturbed_weighted_2 = 24.291028244721005
yt_perturbed_mean_2 = 28.45724771699637

yt_original_10 = 18.42423160728591
yt_perturbed_normal_10 = 29.170916832926327
yt_perturbed_max_10 = 23.922217149563764
yt_perturbed_weighted_10 = 24.83530197485024
yt_perturbed_mean_10 = 29.16461978483078


pt_original_1 = 0.6342269227937665
pt_perturbed_normal_1 = 0.7851353550658506
pt_perturbed_max_1 = 0.8162829290570506
pt_perturbed_weighted_1 = 0.8553443134135907
pt_perturbed_mean_1 = 0.7852156156926509

pt_original_2 = 0.6345080689472311
pt_perturbed_normal_2 = 0.7960056062702023
pt_perturbed_max_2 = 0.8425212010855565
pt_perturbed_weighted_2 = 0.8804150043850969
pt_perturbed_mean_2 = 0.7960878563354082

pt_original_10 = 0.6343311984520739
pt_perturbed_normal_10 = 0.8038017906038962
pt_perturbed_max_10 = 0.8583141671269751
pt_perturbed_weighted_10 = 0.8954368537801611
pt_perturbed_mean_10 = 0.8038704217699788




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "vgg16")

# %% [markdown]
# # Results
#
# Model: vgg16\
# $\epsilon=0.003$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.7156905840980893
accuracy_perturbed_normal_1 = 0.8765925887618475
accuracy_perturbed_max_1 = 0.9132374097337145
accuracy_perturbed_weighted_1 = 0.9559469967654581
accuracy_perturbed_mean_1 = 0.8764727038513616

accuracy_original_2 = 0.715966789529111
accuracy_perturbed_normal_2 = 0.8956601662404092
accuracy_perturbed_max_2 = 0.9679307864450127
accuracy_perturbed_weighted_2 = 0.9873121803069054
accuracy_perturbed_mean_2 = 0.8956801470588235

accuracy_original_10 = 0.7158563073567024
accuracy_perturbed_normal_10 = 0.9111500018805477
accuracy_perturbed_max_10 = 0.9936660805626598
accuracy_perturbed_weighted_10 = 0.996962915601023
accuracy_perturbed_mean_10 = 0.9107703663306755


yt_original_1 = 18.42315607607517
yt_perturbed_normal_1 = 36.4367391069222
yt_perturbed_max_1 = 25.960825229849657
yt_perturbed_weighted_1 = 28.087067584552422
yt_perturbed_mean_1 = 36.42587529301948

yt_original_2 = 18.42477575043583
yt_perturbed_normal_2 = 41.955769204727524
yt_perturbed_max_2 = 29.688120863931562
yt_perturbed_weighted_2 = 30.10601849812071
yt_perturbed_mean_2 = 41.94347832818775

yt_original_10 = 18.423728213590735
yt_perturbed_normal_10 = 47.50136333963145
yt_perturbed_max_10 = 33.75947023718558
yt_perturbed_weighted_10 = 32.387002474206795
yt_perturbed_mean_10 = 47.485118500107085


pt_original_1 = 0.6342812961019824
pt_perturbed_normal_1 = 0.8486220051565438
pt_perturbed_max_1 = 0.8496295481996463
pt_perturbed_weighted_1 = 0.908823994038355
pt_perturbed_mean_1 = 0.8487047392236607

pt_original_2 = 0.634450428473675
pt_perturbed_normal_2 = 0.8756678567822936
pt_perturbed_max_2 = 0.9180172860927289
pt_perturbed_weighted_2 = 0.9612247655001442
pt_perturbed_mean_2 = 0.8756836382171992

pt_original_10 = 0.6343850425594603
pt_perturbed_normal_10 = 0.8950178966192943
pt_perturbed_max_10 = 0.9608251641473502
pt_perturbed_weighted_10 = 0.9866431514015588
pt_perturbed_mean_10 = 0.8949913541831629



iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "vgg16")

# %% [markdown]
# # Results
#
# Model: AlexNet\
# $\epsilon=0.001$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.5654794926282534
accuracy_perturbed_normal_1 = 0.6749496953512862
accuracy_perturbed_max_1 = 0.7460872856175719
accuracy_perturbed_weighted_1 = 0.7605134365127125
accuracy_perturbed_mean_1 = 0.6742703475251993

accuracy_original_2 = 0.5654794926282534
accuracy_perturbed_normal_2 = 0.6791809274860839
accuracy_perturbed_max_2 = 0.7663983752068603
accuracy_perturbed_weighted_2 = 0.7709939634421544
accuracy_perturbed_mean_2 = 0.678621464570483

accuracy_original_10 = 0.5656452158868662
accuracy_perturbed_normal_10 = 0.6824989186851211
accuracy_perturbed_max_10 = 0.7840919775838725
accuracy_perturbed_weighted_10 = 0.7786618963442155
accuracy_perturbed_mean_10 = 0.6825588611403641


yt_original_1 = 14.73085433320926
yt_perturbed_normal_1 = 17.979252115235
yt_perturbed_max_1 = 16.147373515321775
yt_perturbed_weighted_1 = 16.75266264405702
yt_perturbed_mean_1 = 17.971907360779355

yt_original_2 = 14.730096660916457
yt_perturbed_normal_2 = 18.12117033663308
yt_perturbed_max_2 = 16.23833433746377
yt_perturbed_weighted_2 = 16.89171434973207
yt_perturbed_mean_2 = 18.113577952470315

yt_original_10 = 14.732457115827009
yt_perturbed_normal_10 = 18.23754996716824
yt_perturbed_max_10 = 16.312100451925527
yt_perturbed_weighted_10 = 17.005280938599725
yt_perturbed_mean_10 = 18.229764499322837

pt_original_1 = 0.45557294359140077
pt_perturbed_normal_1 = 0.5735203692751467
pt_perturbed_max_1 = 0.5958682011689067
pt_perturbed_weighted_1 = 0.6288805199248712
pt_perturbed_mean_1 = 0.5730798694178881

pt_original_2 = 0.45560412684365004
pt_perturbed_normal_2 = 0.578773647622989
pt_perturbed_max_2 = 0.6054723339007638
pt_perturbed_weighted_2 = 0.6393369082980753
pt_perturbed_mean_2 = 0.5783181390951356

pt_original_10 = 0.4556958661283678
pt_perturbed_normal_10 = 0.5829652057355627
pt_perturbed_max_10 = 0.6113208059383475
pt_perturbed_weighted_10 = 0.6469069616416531
pt_perturbed_mean_10 = 0.5824966152839344




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "AlexNet")

# %% [markdown]
# # Results
#
# Model: AlexNet\
# $\epsilon=0.003$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.5654242515420491
accuracy_perturbed_normal_1 = 0.7716027907326614
accuracy_perturbed_max_1 = 0.8333235388145028
accuracy_perturbed_weighted_1 = 0.8860282364224462
accuracy_perturbed_mean_1 = 0.7709234429065744

accuracy_original_2 = 0.5655347337144576
accuracy_perturbed_normal_2 = 0.7926331897848654
accuracy_perturbed_max_2 = 0.8861387185948548
accuracy_perturbed_weighted_2 = 0.9222440574695351
accuracy_perturbed_mean_2 = 0.7914343406800061

accuracy_original_10 = 0.5654794926282534
accuracy_perturbed_normal_10 = 0.8068947927636527
accuracy_perturbed_max_10 = 0.9278739468933354
accuracy_perturbed_weighted_10 = 0.9423800210621334
accuracy_perturbed_mean_10 = 0.8058757710245223


yt_original_1 = 14.729791102202043
yt_perturbed_normal_1 = 22.43965600396666
yt_perturbed_max_1 = 17.77194587166047
yt_perturbed_weighted_1 = 19.238665453918145
yt_perturbed_mean_1 = 22.42122842588693

yt_original_2 = 14.730452411924787
yt_perturbed_normal_2 = 23.45481460112745
yt_perturbed_max_2 = 18.44465798795071
yt_perturbed_weighted_2 = 20.09027572056217
yt_perturbed_mean_2 = 23.435223767214723

yt_original_10 = 14.728182438999186
yt_perturbed_normal_10 = 24.29332652421254
yt_perturbed_max_10 = 19.001222754378453
yt_perturbed_weighted_10 = 20.89090084846672
yt_perturbed_mean_10 = 24.2724937331646

pt_original_1 = 0.45558808568645925
pt_perturbed_normal_1 = 0.6911658726994644
pt_perturbed_max_1 = 0.6973047355556732
pt_perturbed_weighted_1 = 0.7717930336132683
pt_perturbed_mean_1 = 0.6901832432545665

pt_original_2 = 0.45564275415962
pt_perturbed_normal_2 = 0.7161583315076121
pt_perturbed_max_2 = 0.7450433920716386
pt_perturbed_weighted_2 = 0.8194504146990569
pt_perturbed_mean_2 = 0.7151737341185664

pt_original_10 = 0.4555514530300179
pt_perturbed_normal_10 = 0.7351073419194087
pt_perturbed_max_10 = 0.7772954722956928
pt_perturbed_weighted_10 = 0.8508931340463936
pt_perturbed_mean_10 = 0.7341034010700558




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "AlexNet")

# %% [markdown]
# # Results
#
# Model: googlenet\
# $\epsilon=0.001---$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.6977889461411163
accuracy_perturbed_normal_1 = 0.8434044493756583
accuracy_perturbed_max_1 = 0.8866981815104559
accuracy_perturbed_weighted_1 = 0.9043212633518881
accuracy_perturbed_mean_1 = 0.8470209775086506

accuracy_original_2 = 0.6977889461411163
accuracy_perturbed_normal_2 = 0.8531950503986762
accuracy_perturbed_max_2 = 0.9110395197081391
accuracy_perturbed_weighted_2 = 0.9204457838122461
accuracy_perturbed_mean_2 = 0.8570113867158117

accuracy_original_10 = 0.6977337050549121
accuracy_perturbed_normal_10 = 0.860532712125771
accuracy_perturbed_max_10 = 0.9306113190160975
accuracy_perturbed_weighted_10 = 0.9310908586580413
accuracy_perturbed_mean_10 = 0.865487955092523


yt_original_1 = 9.427390564433145
yt_perturbed_normal_1 = 13.158639206605798
yt_perturbed_max_1 = 11.331613982120134
yt_perturbed_weighted_1 = 12.41871045983356
yt_perturbed_mean_1 = 13.096549384124444

yt_original_2 = 9.427375244667463
yt_perturbed_normal_2 = 13.606806983118473
yt_perturbed_max_2 = 11.62116772073614
yt_perturbed_weighted_2 = 12.808666895112722
yt_perturbed_mean_2 = 13.557083988433604

yt_original_10 = 9.427837601098258
yt_perturbed_normal_10 = 13.979577786477325
yt_perturbed_max_10 = 11.855752574208447
yt_perturbed_weighted_10 = 13.139512895013365
yt_perturbed_mean_10 = 13.934121625807585

pt_original_1 = 0.5496615667248625
pt_perturbed_normal_1 = 0.752549781823707
pt_perturbed_max_1 = 0.74084169594833
pt_perturbed_weighted_1 = 0.7925282318878661
pt_perturbed_mean_1 = 0.7547632997755505

pt_original_2 = 0.5497571711268876
pt_perturbed_normal_2 = 0.7678838523909869
pt_perturbed_max_2 = 0.7635041559138871
pt_perturbed_weighted_2 = 0.8162860214862677
pt_perturbed_mean_2 = 0.7710228539488809

pt_original_10 = 0.5496688834998918
pt_perturbed_normal_10 = 0.7797016457980855
pt_perturbed_max_10 = 0.7784467190885178
pt_perturbed_weighted_10 = 0.8328078685666594
pt_perturbed_mean_10 = 0.7833338416445895




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "GoogLeNet")

# %% [markdown]
# # Results
#
# Model: googlenet\
# $\epsilon=0.003---$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.6977337050549121
accuracy_perturbed_normal_1 = 0.9063792876485632
accuracy_perturbed_max_1 = 0.925021391229126
accuracy_perturbed_weighted_1 = 0.9592085715360312
accuracy_perturbed_mean_1 = 0.909216563863397

accuracy_original_2 = 0.6976784639687077
accuracy_perturbed_normal_2 = 0.9282735632616218
accuracy_perturbed_max_2 = 0.967011668797954
accuracy_perturbed_weighted_2 = 0.984934462915601
accuracy_perturbed_mean_2 = 0.9323696310365579

accuracy_original_10 = 0.6977889461411163
accuracy_perturbed_normal_10 = 0.9447024973672333
accuracy_perturbed_max_10 = 0.9902693414322251
accuracy_perturbed_weighted_10 = 0.9943853900255755
accuracy_perturbed_mean_10 = 0.9488585075974123


yt_original_1 = 9.427244260792842
yt_perturbed_normal_1 = 16.02694666416139
yt_perturbed_max_1 = 12.598835258532668
yt_perturbed_weighted_1 = 14.632407462810312
yt_perturbed_mean_1 = 15.902013249409473

yt_original_2 = 9.42789774843494
yt_perturbed_normal_2 = 18.131528761685658
yt_perturbed_max_2 = 13.935417707009083
yt_perturbed_weighted_2 = 16.28083608583416
yt_perturbed_mean_2 = 18.058502946058503

yt_original_10 = 9.427894144716776
yt_perturbed_normal_10 = 20.45338443356097
yt_perturbed_max_10 = 15.388802488136779
yt_perturbed_weighted_10 = 18.257119566583267
yt_perturbed_mean_10 = 20.375723038792916

pt_original_1 = 0.5496926329782247
pt_perturbed_normal_1 = 0.8465925471861954
pt_perturbed_max_1 = 0.8102146310117239
pt_perturbed_weighted_1 = 0.8855527281913611
pt_perturbed_mean_1 = 0.8482800072721203

pt_original_2 = 0.5496894214921595
pt_perturbed_normal_2 = 0.8832490905319028
pt_perturbed_max_2 = 0.8748337861217196
pt_perturbed_weighted_2 = 0.9382326506135409
pt_perturbed_mean_2 = 0.8869338287874255

pt_original_10 = 0.5497221202420457
pt_perturbed_normal_10 = 0.9102356591645409
pt_perturbed_max_10 = 0.9196226967265234
pt_perturbed_weighted_10 = 0.9686722997814188
pt_perturbed_mean_10 = 0.9141142878233625




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "GoogLeNet")

# %% [markdown]
# # Results
#
# Model: resnet18\
# $\epsilon=0.001$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.6975385982398075
accuracy_perturbed_normal_1 = 0.8377099161275764
accuracy_perturbed_max_1 = 0.8965886866255454
accuracy_perturbed_weighted_1 = 0.9193068771626297
accuracy_perturbed_mean_1 = 0.8377099161275764

accuracy_original_2 = 0.6974281160673987
accuracy_perturbed_normal_2 = 0.8460818790431774
accuracy_perturbed_max_2 = 0.9215447288250338
accuracy_perturbed_weighted_2 = 0.9371050850007523
accuracy_perturbed_mean_2 = 0.8460419174063488

accuracy_original_10 = 0.6974281160673987
accuracy_perturbed_normal_10 = 0.853219732586129
accuracy_perturbed_max_10 = 0.940646391229126
accuracy_perturbed_weighted_10 = 0.9468604257559802
accuracy_perturbed_mean_10 = 0.8532397134045434


yt_original_1 = 15.55476177927783
yt_perturbed_normal_1 = 22.01927684579054
yt_perturbed_max_1 = 18.46662316724772
yt_perturbed_weighted_1 = 19.540761076885723
yt_perturbed_mean_1 = 22.01929175335428

yt_original_2 = 15.551799010742656
yt_perturbed_normal_2 = 22.672847184378778
yt_perturbed_max_2 = 18.889155704956835
yt_perturbed_weighted_2 = 20.082844548822973
yt_perturbed_mean_2 = 22.672852499100863

yt_original_10 = 15.552248562083525
yt_perturbed_normal_10 = 23.215255166563537
yt_perturbed_max_10 = 19.231754820060242
yt_perturbed_weighted_10 = 20.53758382187475
yt_perturbed_mean_10 = 23.215234107678505

pt_original_1 = 0.6085833995162374
pt_perturbed_normal_1 = 0.7821266795973034
pt_perturbed_max_1 = 0.80958222504467
pt_perturbed_weighted_1 = 0.8486000701899419
pt_perturbed_mean_1 = 0.7821242997560964

pt_original_2 = 0.6084924555571792
pt_perturbed_normal_2 = 0.7934955494178225
pt_perturbed_max_2 = 0.8321594826095854
pt_perturbed_weighted_2 = 0.8711366662588875
pt_perturbed_mean_2 = 0.7934921166628522

pt_original_10 = 0.6084839996245816
pt_perturbed_normal_10 = 0.8024423353354949
pt_perturbed_max_10 = 0.8459884374952682
pt_perturbed_weighted_10 = 0.8854281236143673
pt_perturbed_mean_10 = 0.8024379990594771




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "resnet18")

# %% [markdown]
# # Results
#
# Model: resnet18\
# $\epsilon=0.003$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.6975938393260118
accuracy_perturbed_normal_1 = 0.902762759515571
accuracy_perturbed_max_1 = 0.9385237231081691
accuracy_perturbed_weighted_1 = 0.9701933202948699
accuracy_perturbed_mean_1 = 0.9027227978787423

accuracy_original_2 = 0.6976490804122161
accuracy_perturbed_normal_2 = 0.9232430983902512
accuracy_perturbed_max_2 = 0.9781010230179028
accuracy_perturbed_weighted_2 = 0.9924872122762148
accuracy_perturbed_mean_2 = 0.9232430983902512

accuracy_original_10 = 0.6975938393260118
accuracy_perturbed_normal_10 = 0.9375646438242817
accuracy_perturbed_max_10 = 0.9949648337595908
accuracy_perturbed_weighted_10 = 0.9974424552429667
accuracy_perturbed_mean_10 = 0.9375446630058674


yt_original_1 = 15.556074382703933
yt_perturbed_normal_1 = 27.988823329701145
yt_perturbed_max_1 = 20.703518194310806
yt_perturbed_weighted_1 = 22.85537345086217
yt_perturbed_mean_1 = 27.98886662066135

yt_original_2 = 15.557718472102719
yt_perturbed_normal_2 = 31.509287465868702
yt_perturbed_max_2 = 22.841748742496264
yt_perturbed_weighted_2 = 24.96371058003067
yt_perturbed_mean_2 = 31.509319134685388

yt_original_10 = 15.553052827830205
yt_perturbed_normal_10 = 35.12359033033366
yt_perturbed_max_10 = 25.08324737012234
yt_perturbed_weighted_10 = 26.882579140041184
yt_perturbed_mean_10 = 35.12352386581928

pt_original_1 = 0.6086428841514051
pt_perturbed_normal_1 = 0.8674390771809746
pt_perturbed_max_1 = 0.8743664424132813
pt_perturbed_weighted_1 = 0.927341805775757
pt_perturbed_mean_1 = 0.8674363004582007

pt_original_2 = 0.6086593416645704
pt_perturbed_normal_2 = 0.8954752059391392
pt_perturbed_max_2 = 0.9297178601060072
pt_perturbed_weighted_2 = 0.9692762221979059
pt_perturbed_mean_2 = 0.8954738383098026

pt_original_10 = 0.6085428341346628
pt_perturbed_normal_10 = 0.9156889192893377
pt_perturbed_max_10 = 0.9628038529849723
pt_perturbed_weighted_10 = 0.9876882985729696
pt_perturbed_mean_10 = 0.9156697043372543




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "resnet18")

# %% [markdown]
# # Results
#
# Model: MobileNetV3Small\
# $\epsilon=0.001$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.6766034019106364
accuracy_perturbed_normal_1 = 0.8538391379569731
accuracy_perturbed_max_1 = 0.8877971265232436
accuracy_perturbed_weighted_1 = 0.9152061080186551
accuracy_perturbed_mean_1 = 0.6555788795697307

accuracy_original_2 = 0.676548160824432
accuracy_perturbed_normal_2 = 0.8663682864450127
accuracy_perturbed_max_2 = 0.9148617327365729
accuracy_perturbed_weighted_2 = 0.932664641943734
accuracy_perturbed_mean_2 = 0.6586500488942381

accuracy_original_10 = 0.6767691251692493
accuracy_perturbed_normal_10 = 0.8740350440048142
accuracy_perturbed_max_10 = 0.9349271757935912
accuracy_perturbed_weighted_10 = 0.9416407307808035
accuracy_perturbed_mean_10 = 0.6591754268843086


yt_original_1 = 12.729510185358775
yt_perturbed_normal_1 = 17.40959386996296
yt_perturbed_max_1 = 15.119060115131271
yt_perturbed_weighted_1 = 15.985590871337735
yt_perturbed_mean_1 = 11.073796327156789

yt_original_2 = 12.72941480085368
yt_perturbed_normal_2 = 17.88718741751083
yt_perturbed_max_2 = 15.410597018268712
yt_perturbed_weighted_2 = 16.34957791594288
yt_perturbed_mean_2 = 11.042520488924383

yt_original_10 = 12.730365128773252
yt_perturbed_normal_10 = 18.22566004116517
yt_perturbed_max_10 = 15.582384902193114
yt_perturbed_weighted_10 = 16.613430335393648
yt_perturbed_mean_10 = 11.000950570606514

pt_original_1 = 0.5855987008346621
pt_perturbed_normal_1 = 0.78465799678622
pt_perturbed_max_1 = 0.7940353987466954
pt_perturbed_weighted_1 = 0.836710478338744
pt_perturbed_mean_1 = 0.5160614806977685

pt_original_2 = 0.58548091851232
pt_perturbed_normal_2 = 0.8002125806058459
pt_perturbed_max_2 = 0.8180217575996428
pt_perturbed_weighted_2 = 0.8602278991733365
pt_perturbed_mean_2 = 0.5141157182814825

pt_original_10 = 0.5856775229468065
pt_perturbed_normal_10 = 0.810550173301526
pt_perturbed_max_10 = 0.8312917347149471
pt_perturbed_weighted_10 = 0.8738233931076801
pt_perturbed_mean_10 = 0.5112534788106103




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "MobileNetV3Small")

# %% [markdown]
# # Results
#
# Model: MobileNetV3Small\
# $\epsilon=0.003$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.676713884083045
accuracy_perturbed_normal_1 = 0.9217151534526854
accuracy_perturbed_max_1 = 0.9267503196930946
accuracy_perturbed_weighted_1 = 0.9652733375959079
accuracy_perturbed_mean_1 = 0.5452847619226718

accuracy_original_2 = 0.6766034019106364
accuracy_perturbed_normal_2 = 0.9500726361516474
accuracy_perturbed_max_2 = 0.9738697908831052
accuracy_perturbed_weighted_2 = 0.9913929686324658
accuracy_perturbed_mean_2 = 0.5768344741988867

accuracy_original_10 = 0.6767691251692493
accuracy_perturbed_normal_10 = 0.9658175210621334
accuracy_perturbed_max_10 = 0.9945252557544757
accuracy_perturbed_weighted_10 = 0.9976422634271099
accuracy_perturbed_mean_10 = 0.5714655107567324


yt_original_1 = 12.730155397254183
yt_perturbed_normal_1 = 20.54464733143292
yt_perturbed_max_1 = 16.17561402406229
yt_perturbed_weighted_1 = 17.804888610644717
yt_perturbed_mean_1 = 8.958713284538835

yt_original_2 = 12.728237675278997
yt_perturbed_normal_2 = 23.18541869726937
yt_perturbed_max_2 = 17.86925568422088
yt_perturbed_weighted_2 = 19.51852478944432
yt_perturbed_mean_2 = 9.06427457082607

yt_original_10 = 12.730367945893036
yt_perturbed_normal_10 = 25.694453561397463
yt_perturbed_max_10 = 19.28045606491206
yt_perturbed_weighted_10 = 20.959406774672097
yt_perturbed_mean_10 = 8.847535464464857

pt_original_1 = 0.5856139947615011
pt_perturbed_normal_1 = 0.8694807232340889
pt_perturbed_max_1 = 0.8485518857036405
pt_perturbed_weighted_1 = 0.9116998658613171
pt_perturbed_mean_1 = 0.36067595740642083

pt_original_2 = 0.5855333225044144
pt_perturbed_normal_2 = 0.9150481663853921
pt_perturbed_max_2 = 0.9189028058515485
pt_perturbed_weighted_2 = 0.9652752123982705
pt_perturbed_mean_2 = 0.3528473763286

pt_original_10 = 0.5857115963764508
pt_perturbed_normal_10 = 0.9394845749868457
pt_perturbed_max_10 = 0.9589339324732875
pt_perturbed_weighted_10 = 0.9870473878158023
pt_perturbed_mean_10 = 0.31623406725390185




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "MobileNetV3Small")

# %% [markdown]
# # Results
#
# Model: MobileNetV3Large\
# $\epsilon=0.001$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.7405678783661802
accuracy_perturbed_normal_1 = 0.8948503554234993
accuracy_perturbed_max_1 = 0.9243972844892433
accuracy_perturbed_weighted_1 = 0.9440384289905221
accuracy_perturbed_mean_1 = 0.720516539416278

accuracy_original_2 = 0.7406231194523846
accuracy_perturbed_normal_2 = 0.9031271156160675
accuracy_perturbed_max_2 = 0.9428243004362871
accuracy_perturbed_weighted_2 = 0.9569907006920415
accuracy_perturbed_mean_2 = 0.7209819749511058

accuracy_original_10 = 0.7404021551075674
accuracy_perturbed_normal_10 = 0.908182262674891
accuracy_perturbed_max_10 = 0.9570153828794946
accuracy_perturbed_weighted_10 = 0.962725195576952
accuracy_perturbed_mean_10 = 0.720541221603731


yt_original_1 = 15.687885807603216
yt_perturbed_normal_1 = 21.835510470983014
yt_perturbed_max_1 = 19.011239307920647
yt_perturbed_weighted_1 = 19.7254174273947
yt_perturbed_mean_1 = 13.160807054670876

yt_original_2 = 15.69176459129509
yt_perturbed_normal_2 = 22.434480045152746
yt_perturbed_max_2 = 19.418543296092
yt_perturbed_weighted_2 = 20.084905663414684
yt_perturbed_mean_2 = 13.040872040916891

yt_original_10 = 15.687720553649356
yt_perturbed_normal_10 = 22.838720455803834
yt_perturbed_max_10 = 19.666051884136543
yt_perturbed_weighted_10 = 20.2624705795132
yt_perturbed_mean_10 = 12.930140208710185

pt_original_1 = 0.6865485694707202
pt_perturbed_normal_1 = 0.8611580194414729
pt_perturbed_max_1 = 0.8784336004873066
pt_perturbed_weighted_1 = 0.9054295326132908
pt_perturbed_mean_1 = 0.6207247133678793

pt_original_2 = 0.686619853805703
pt_perturbed_normal_2 = 0.8717355729673829
pt_perturbed_max_2 = 0.8975233011843299
pt_perturbed_weighted_2 = 0.9226695049144423
pt_perturbed_mean_2 = 0.6159477814307908

pt_original_10 = 0.6864828702129061
pt_perturbed_normal_10 = 0.8783169401728589
pt_perturbed_max_10 = 0.907658994045404
pt_perturbed_weighted_10 = 0.9316640363629821
pt_perturbed_mean_10 = 0.6110682522930453




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "MobileNetV3Large")

# %% [markdown]
# # Results
#
# Model: MobileNetV3Large\
# $\epsilon=0.003$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.740512637279976
accuracy_perturbed_normal_1 = 0.9504475703324808
accuracy_perturbed_max_1 = 0.9577405690537084
accuracy_perturbed_weighted_1 = 0.9785006393861893
accuracy_perturbed_mean_1 = 0.6240044851060629

accuracy_original_2 = 0.7405678783661802
accuracy_perturbed_normal_2 = 0.9680107097186701
accuracy_perturbed_max_2 = 0.9866375338498572
accuracy_perturbed_weighted_2 = 0.9950847186700768
accuracy_perturbed_mean_2 = 0.6355839570482924

accuracy_original_10 = 0.7405678783661802
accuracy_perturbed_normal_10 = 0.9769421355498721
accuracy_perturbed_max_10 = 0.9971027813299232
accuracy_perturbed_weighted_10 = 0.9988411125319693
accuracy_perturbed_mean_10 = 0.6175600834963141


yt_original_1 = 15.688215853308169
yt_perturbed_normal_1 = 26.53693605749808
yt_perturbed_max_1 = 20.858773792491238
yt_perturbed_weighted_1 = 22.258475893903572
yt_perturbed_mean_1 = 10.518628947265313

yt_original_2 = 15.68967129690263
yt_perturbed_normal_2 = 30.10829703338311
yt_perturbed_max_2 = 23.274650927394855
yt_perturbed_weighted_2 = 23.664549859283525
yt_perturbed_mean_2 = 10.20767746435102

yt_original_10 = 15.689264192605567
yt_perturbed_normal_10 = 33.686543115874386
yt_perturbed_max_10 = 25.445576487294854
yt_perturbed_weighted_10 = 24.093307307309203
yt_perturbed_mean_10 = 9.722655519500108

pt_original_1 = 0.6865369788825969
pt_perturbed_normal_1 = 0.9282862405337946
pt_perturbed_max_1 = 0.9243321791481789
pt_perturbed_weighted_1 = 0.956757188453089
pt_perturbed_mean_1 = 0.4628242391835698

pt_original_2 = 0.6866169917918837
pt_perturbed_normal_2 = 0.9539956137194963
pt_perturbed_max_2 = 0.9680686442138594
pt_perturbed_weighted_2 = 0.986600942852552
pt_perturbed_mean_2 = 0.43254541199835367

pt_original_10 = 0.6865684591290896
pt_perturbed_normal_10 = 0.9669092962961368
pt_perturbed_max_10 = 0.9875068956476343
pt_perturbed_weighted_10 = 0.9960284656118554
pt_perturbed_mean_10 = 0.37528236572394896




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "MobileNetV3Large")

# %% [markdown]
# # Results
#
# Model: MnasNet\
# $\epsilon=0.001$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.7347687396569882
accuracy_perturbed_normal_1 = 0.8809237249887167
accuracy_perturbed_max_1 = 0.9325447570332481
accuracy_perturbed_weighted_1 = 0.9519061700767263
accuracy_perturbed_mean_1 = 0.8809037441703024

accuracy_original_2 = 0.734547775312171
accuracy_perturbed_normal_2 = 0.8909294136452536
accuracy_perturbed_max_2 = 0.9551630434782609
accuracy_perturbed_weighted_2 = 0.9678109015345269
accuracy_perturbed_mean_2 = 0.8909094328268392

accuracy_original_10 = 0.7348239807431924
accuracy_perturbed_normal_10 = 0.8984621821874531
accuracy_perturbed_max_10 = 0.9699088874680307
accuracy_perturbed_weighted_10 = 0.9750439578005116
accuracy_perturbed_mean_10 = 0.8984022397322101


yt_original_1 = 18.476917405872396
yt_perturbed_normal_1 = 27.22201469548218
yt_perturbed_max_1 = 22.585563574300703
yt_perturbed_weighted_1 = 23.676935859348465
yt_perturbed_mean_1 = 27.22219679361719

yt_original_2 = 18.47484931311644
yt_perturbed_normal_2 = 28.37625604029507
yt_perturbed_max_2 = 23.32844198085463
yt_perturbed_weighted_2 = 24.38707657055477
yt_perturbed_mean_2 = 28.376349873554982

yt_original_10 = 18.478128394202503
yt_perturbed_normal_10 = 29.304106000134404
yt_perturbed_max_10 = 23.92229067029246
yt_perturbed_weighted_10 = 24.916498674456115
yt_perturbed_mean_10 = 29.304140764124252

pt_original_1 = 0.6674877158973528
pt_perturbed_normal_1 = 0.84383994577181
pt_perturbed_max_1 = 0.8764737369611745
pt_perturbed_weighted_1 = 0.9076712331960878
pt_perturbed_mean_1 = 0.8437942274086311

pt_original_2 = 0.66731705293631
pt_perturbed_normal_2 = 0.8567863018311503
pt_perturbed_max_2 = 0.9013417019411121
pt_perturbed_weighted_2 = 0.9310087768165657
pt_perturbed_mean_2 = 0.8567362963543523

pt_original_10 = 0.6674676205191161
pt_perturbed_normal_10 = 0.8661082281023645
pt_perturbed_max_10 = 0.9162950824441203
pt_perturbed_weighted_10 = 0.9441573238738662
pt_perturbed_mean_10 = 0.8660641760015122




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "MnasNet")

# %% [markdown]
# # Results
#
# Model: MnasNet\
# $\epsilon=0.003$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 0.7346582574845796
accuracy_perturbed_normal_1 = 0.927973850985407
accuracy_perturbed_max_1 = 0.9587795716112532
accuracy_perturbed_weighted_1 = 0.9802389705882353
accuracy_perturbed_mean_1 = 0.9279338893485783

accuracy_original_2 = 0.7346582574845796
accuracy_perturbed_normal_2 = 0.9463761847449979
accuracy_perturbed_max_2 = 0.9886708759590793
accuracy_perturbed_weighted_2 = 0.9968829923273658
accuracy_perturbed_mean_2 = 0.9462562998345119

accuracy_original_10 = 0.7346030163983752
accuracy_perturbed_normal_10 = 0.9591838893485783
accuracy_perturbed_max_10 = 0.9986612851662404
accuracy_perturbed_weighted_10 = 0.9995004795396419
accuracy_perturbed_mean_10 = 0.9593836975327216


yt_original_1 = 18.47489809563093
yt_perturbed_normal_1 = 33.453523033415266
yt_perturbed_max_1 = 24.875434236453316
yt_perturbed_weighted_1 = 26.871049232190224
yt_perturbed_mean_1 = 33.45394734287506

yt_original_2 = 18.475432541059412
yt_perturbed_normal_2 = 39.013642303778994
yt_perturbed_max_2 = 28.282334888682644
yt_perturbed_weighted_2 = 28.843594165714194
yt_perturbed_mean_2 = 39.01405838383433

yt_original_10 = 18.474073046613533
yt_perturbed_normal_10 = 45.19632378990388
yt_perturbed_max_10 = 32.00526181145397
yt_perturbed_weighted_10 = 29.996942203063185
yt_perturbed_mean_10 = 45.19611444009844

pt_original_1 = 0.6673124392166772
pt_perturbed_normal_1 = 0.9049072978289231
pt_perturbed_max_1 = 0.9164593359241096
pt_perturbed_weighted_1 = 0.953392799248171
pt_perturbed_mean_1 = 0.9048634532010159

pt_original_2 = 0.6673608639508563
pt_perturbed_normal_2 = 0.930763137767382
pt_perturbed_max_2 = 0.9648132409586017
pt_perturbed_weighted_2 = 0.9867855777673404
pt_perturbed_mean_2 = 0.9307311069782432

pt_original_10 = 0.6672909439677168
pt_perturbed_normal_10 = 0.9484214073099444
pt_perturbed_max_10 = 0.9885473089754734
pt_perturbed_weighted_10 = 0.9973464047207552
pt_perturbed_mean_10 = 0.9483588140486451




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "MnasNet")

# %% [markdown]
# # Results
#
# Model: ---\
# $\epsilon=0.00---$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 
accuracy_perturbed_normal_1 = 
accuracy_perturbed_max_1 = 
accuracy_perturbed_weighted_1 = 
accuracy_perturbed_mean_1 = 

accuracy_original_2 = 
accuracy_perturbed_normal_2 = 
accuracy_perturbed_max_2 = 
accuracy_perturbed_weighted_2 = 
accuracy_perturbed_mean_2 = 

accuracy_original_10 = 
accuracy_perturbed_normal_10 = 
accuracy_perturbed_max_10 = 
accuracy_perturbed_weighted_10 = 
accuracy_perturbed_mean_10 = 


yt_original_1 = 
yt_perturbed_normal_1 = 
yt_perturbed_max_1 = 
yt_perturbed_weighted_1 = 
yt_perturbed_mean_1 = 

yt_original_2 = 
yt_perturbed_normal_2 = 
yt_perturbed_max_2 = 
yt_perturbed_weighted_2 = 
yt_perturbed_mean_2 = 

yt_original_10 = 
yt_perturbed_normal_10 = 
yt_perturbed_max_10 = 
yt_perturbed_weighted_10 = 
yt_perturbed_mean_10 = 

pt_original_1 = 
pt_perturbed_normal_1 = 
pt_perturbed_max_1 = 
pt_perturbed_weighted_1 = 
pt_perturbed_mean_1 = 

pt_original_2 = 
pt_perturbed_normal_2 = 
pt_perturbed_max_2 = 
pt_perturbed_weighted_2 = 
pt_perturbed_mean_2 = 

pt_original_10 = 
pt_perturbed_normal_10 = 
pt_perturbed_max_10 = 
pt_perturbed_weighted_10 = 
pt_perturbed_mean_10 = 




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "---")

# %% [markdown]
# # Results
#
# Model: ---\
# $\epsilon=0.00---$\
# Dataset: Entire validationset of ILSVRC2012

# %%
accuracy_original_1 = 
accuracy_perturbed_normal_1 = 
accuracy_perturbed_max_1 = 
accuracy_perturbed_weighted_1 = 
accuracy_perturbed_mean_1 = 

accuracy_original_2 = 
accuracy_perturbed_normal_2 = 
accuracy_perturbed_max_2 = 
accuracy_perturbed_weighted_2 = 
accuracy_perturbed_mean_2 = 

accuracy_original_10 = 
accuracy_perturbed_normal_10 = 
accuracy_perturbed_max_10 = 
accuracy_perturbed_weighted_10 = 
accuracy_perturbed_mean_10 = 


yt_original_1 = 
yt_perturbed_normal_1 = 
yt_perturbed_max_1 = 
yt_perturbed_weighted_1 = 
yt_perturbed_mean_1 = 

yt_original_2 = 
yt_perturbed_normal_2 = 
yt_perturbed_max_2 = 
yt_perturbed_weighted_2 = 
yt_perturbed_mean_2 = 

yt_original_10 = 
yt_perturbed_normal_10 = 
yt_perturbed_max_10 = 
yt_perturbed_weighted_10 = 
yt_perturbed_mean_10 = 

pt_original_1 = 
pt_perturbed_normal_1 = 
pt_perturbed_max_1 = 
pt_perturbed_weighted_1 = 
pt_perturbed_mean_1 = 

pt_original_2 = 
pt_perturbed_normal_2 = 
pt_perturbed_max_2 = 
pt_perturbed_weighted_2 = 
pt_perturbed_mean_2 = 

pt_original_10 = 
pt_perturbed_normal_10 = 
pt_perturbed_max_10 = 
pt_perturbed_weighted_10 = 
pt_perturbed_mean_10 = 




iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "---")

# %% [markdown]
# #

# %%
# Initialization

import torch
import torch.nn as nn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt

device = "cuda:0" if torch.cuda.is_available() else "cpu" # If using GPU then use mixed precision training.

# Load ImageNet

data_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

normalization = transforms.Compose([
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

data_dir = '../ILSVRC2012'
val_dataset = datasets.ImageNet(root=data_dir, split='val', transform=data_transforms)

BATCH_SIZE = 64

dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True)
#dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
dataset_sizes = len(val_dataset)
class_names = val_dataset.classes

def get_model(model_type):
    model = torch.hub.load('pytorch/vision:v0.10.0', model_type, pretrained=True).to(device)
    return model

def evaluate_model(model, images_no_norm, labels):
    
    images = normalization(images_no_norm.clone().detach())
    
    was_training = model.training
    model.eval()
    num_images = images.size()[0]

    with torch.no_grad():
        outputs = model(images)
        
        yt_average = outputs[torch.arange(outputs.size(0)), labels].mean().item()
        
        outputs_pt = torch.softmax(outputs, dim=1)
        pt_average = outputs_pt[torch.arange(outputs_pt.size(0)), labels].mean().item()
        
        _, preds = torch.max(outputs, 1)
        correct_classifications = (preds == labels).sum().item()
        accuracy = correct_classifications / num_images

        return accuracy, yt_average, pt_average


def get_explanation(model, inputs_no_norm, targets, explanation_mode):
    model.eval()

    inputs = normalization(inputs_no_norm.clone().detach())

    inputs.requires_grad = True
    model.zero_grad()

    outputs = model(inputs)

    if explanation_mode == 'normal':
        loss = outputs[torch.arange(outputs.size(0)), targets ].sum()
    elif explanation_mode == 'max':
        probs, preds = torch.topk(outputs, 2)
        correct_classifications = preds[:, 0] == targets
        wrong_classifications = preds[:, 0] != targets
        max_index_not_target = correct_classifications * preds[:, 1] + wrong_classifications * preds[:, 0]
        #loss = ( outputs[torch.arange(outputs.size(0)), targets ] - outputs[torch.arange(outputs.size(0)), preds[:,1] ] ).sum()
        loss = ( outputs[torch.arange(outputs.size(0)), targets ] - outputs[torch.arange(outputs.size(0)), max_index_not_target ] ).sum()
    elif explanation_mode == 'weighted':
        outputs = torch.softmax(outputs, dim=1)
        loss = outputs[torch.arange(outputs.size(0)), targets ].sum()
    elif explanation_mode == 'mean':
        #loss = ( outputs[torch.arange(outputs.size(0)), targets ] * (1 + 1/( 1 - 1000 )) - torch.sum(outputs[torch.arange(outputs.size(0))]) * 1/(( 1 - 1000 )) ).sum()
        
        weights = -torch.ones(outputs.shape).to(outputs.device)/999
        weights[range(len(weights)), targets] = 1
        loss = (weights * outputs).sum()
        loss = outputs[range(len(outputs)), targets].sum()
        
        #weights = -torch.ones(outputs.shape).to(outputs.device)/999
        #weights[range(len(weights)), targets] = 1
        #loss = (weights * outputs).sum()
        #loss = pred[range(len(pred)), label].sum()

    loss.backward()
    gradients = inputs.grad.clone().detach()
    explanations = gradients
    inputs.requires_grad = False

    return explanations


def grad_sign_perturb(model, inputs_no_norm, targets, no_iterations, eps, explanation_mode):
    x_0 = inputs_no_norm
    x_i = inputs_no_norm
    alpha = eps / no_iterations
    
    for i in range(no_iterations):
        explanations = get_explanation(model, x_i, targets, explanation_mode)

        # gradients on shape [labels, batch, ...input gradients...]
        
        x_i = x_i + alpha * torch.sign(explanations)
        #x_i = torch.clamp( x_i, torch.max(x_0-eps, 0, keepdim=True).values, torch.min(x_0+eps, 1, keepdim=True).values )
        x_i = torch.clamp(x_i, x_0-eps, x_0+eps)
        x_i = torch.clamp(x_i, 0, 1)

    return x_i


def experiment(dataloader, device, model, no_iterations, no_batches = None, eps=0.001 ):
    
    accuracy_original_total = 0
    accuracy_perturbed_normal_total = 0
    accuracy_perturbed_max_total = 0
    accuracy_perturbed_weighted_total = 0
    accuracy_perturbed_mean_total = 0
    
    yt_original_total = 0
    yt_perturbed_normal_total = 0
    yt_perturbed_max_total = 0
    yt_perturbed_weighted_total = 0
    yt_perturbed_mean_total = 0
    
    pt_original_total = 0
    pt_perturbed_normal_total = 0
    pt_perturbed_max_total = 0
    pt_perturbed_weighted_total = 0
    pt_perturbed_mean_total = 0   

    batch_iter = 0
    for batch in iter(dataloader):
        if no_batches != None and batch_iter >= no_batches:
            break
        batch_iter += 1
        
        inputs, targets = batch
        inputs = inputs.to(device)
        targets = targets.to(device)

        perturbed_inputs_normal = grad_sign_perturb(model, inputs, targets, no_iterations, eps, 'normal')
        perturbed_inputs_max = grad_sign_perturb(model, inputs, targets, no_iterations, eps, 'max')
        perturbed_inputs_weighted = grad_sign_perturb(model, inputs, targets, no_iterations, eps, 'weighted')
        perturbed_inputs_mean = grad_sign_perturb(model, inputs, targets, no_iterations, eps, 'mean')

        accuracy_original, yt_original, pt_original = evaluate_model(model, inputs, targets)
        accuracy_perturbed_normal, yt_perturbed_normal, pt_perturbed_normal = evaluate_model(model, perturbed_inputs_normal, targets)
        accuracy_perturbed_max, yt_perturbed_max, pt_perturbed_max = evaluate_model(model, perturbed_inputs_max, targets)
        accuracy_perturbed_weighted, yt_perturbed_weighted, pt_perturbed_weighted = evaluate_model(model, perturbed_inputs_weighted, targets)
        accuracy_perturbed_mean, yt_perturbed_mean, pt_perturbed_mean = evaluate_model(model, perturbed_inputs_mean, targets)
        

        accuracy_original_total += accuracy_original
        accuracy_perturbed_normal_total += accuracy_perturbed_normal
        accuracy_perturbed_max_total += accuracy_perturbed_max
        accuracy_perturbed_weighted_total += accuracy_perturbed_weighted
        accuracy_perturbed_mean_total += accuracy_perturbed_mean
        
        yt_original_total += yt_original
        yt_perturbed_normal_total += yt_perturbed_normal
        yt_perturbed_max_total += yt_perturbed_max
        yt_perturbed_weighted_total += yt_perturbed_weighted
        yt_perturbed_mean_total += yt_perturbed_mean
        
        pt_original_total += pt_original
        pt_perturbed_normal_total += pt_perturbed_normal
        pt_perturbed_max_total += pt_perturbed_max
        pt_perturbed_weighted_total += pt_perturbed_weighted
        pt_perturbed_mean_total += pt_perturbed_mean
        
        if (batch_iter % 50 == 0):
            print("batch: ", batch_iter)


    accuracy_original = accuracy_original_total / batch_iter
    accuracy_perturbed_normal = accuracy_perturbed_normal_total / batch_iter
    accuracy_perturbed_max = accuracy_perturbed_max_total / batch_iter
    accuracy_perturbed_weighted = accuracy_perturbed_weighted_total / batch_iter
    accuracy_perturbed_mean = accuracy_perturbed_mean_total / batch_iter
    
    yt_original = yt_original_total / batch_iter
    yt_perturbed_normal = yt_perturbed_normal_total / batch_iter
    yt_perturbed_max = yt_perturbed_max_total / batch_iter
    yt_perturbed_weighted = yt_perturbed_weighted_total / batch_iter
    yt_perturbed_mean = yt_perturbed_mean_total / batch_iter
    
    pt_original = pt_original_total / batch_iter
    pt_perturbed_normal = pt_perturbed_normal_total / batch_iter
    pt_perturbed_max = pt_perturbed_max_total / batch_iter
    pt_perturbed_weighted = pt_perturbed_weighted_total / batch_iter
    pt_perturbed_mean = pt_perturbed_mean_total / batch_iter
    

    return accuracy_original, accuracy_perturbed_normal, accuracy_perturbed_max, accuracy_perturbed_weighted, accuracy_perturbed_mean, \
           yt_original, yt_perturbed_normal, yt_perturbed_max, yt_perturbed_weighted, yt_perturbed_mean, \
           pt_original, pt_perturbed_normal, pt_perturbed_max, pt_perturbed_weighted, pt_perturbed_mean


def plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, title):

    x = np.arange(4)
    width = 0.07
    distance = 0.035
    
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()

    iter1acc_t_bar = ax2.bar(x-4*width-distance, iter1acc_t, width, color='#333333')
    iter1p_t_bar = ax2.bar(x-3*width-distance, iter1p_t, width, color='#878787')
    iter1y_t_bar = ax1.bar(x-2*width-distance, iter1y_t, width, color='#c0c0c0')

    iter2acc_t_bar = ax2.bar(x-width, iter2acc_t, width, color='#ff3333')
    iter2p_t_bar = ax2.bar(x, iter2p_t, width, color='#ffa333')
    iter2y_t_bar = ax1.bar(x+width, iter2y_t, width, color='#ffe4c4')

    iter10acc_t_bar = ax2.bar(x+2*width+distance, iter10acc_t, width, color='#3333ff')
    iter10p_t_bar = ax2.bar(x+3*width+distance, iter10p_t, width, color='#6787e7')
    iter10y_t_bar = ax1.bar(x+4*width+distance, iter10y_t, width, color='#b0c4de')

    #ax1.set_xticks(x, ['Weighted', 'Original', 'Mean', 'Max'])
    ax1.set_xticks(x)
    ax1.set_xticklabels(['Weighted', 'Original', 'Mean', 'Max'])
    
    ax1.set_ylabel('Changes over $y_t$ (one challow bar)')
    ax2.set_ylabel('Changes over $p_t$ and Accuracy (two dark bars)')
    
    fig.legend([iter1acc_t_bar, iter1p_t_bar, iter1y_t_bar,
                iter2acc_t_bar, iter2p_t_bar, iter2y_t_bar,
                iter10acc_t_bar, iter10p_t_bar, iter10y_t_bar],
               ["iteration 1, accuracy", "iteration 1, avg. $p_t$", "iteration 1, avg. $y_t$",
                "iteration 2, accuracy", "iteration 2, avg. $p_t$", "iteration 2, avg. $y_t$",
                "iteration 10, accuracy", "iteration 10, avg. $p_t$", "iteration 10, avg. $y_t$"],
               loc='upper center', bbox_to_anchor=(0.5, -0.07), fancybox=True, shadow=True, ncol=3)
    
    plt.title(title)
    plt.show(block=True)
    
    
if __name__ == '__main__':
    
    
    #model = get_model('vgg16')
    #model = get_model('alexnet')
    
    # resnet18
    # googlenet
    # 
    # mobilenet_v3_large
    # mnasnet1_0

    for architecture in ['mobilenet_v3_small']: #'densenet161',
        model = get_model(architecture)
        print("--------------------Network: ", architecture, "--------------------")

        for epsilon in [0.001, 0.003]:
            print("----------Epsilon: ", epsilon, "----------")

            print("no_iterations: 1")
            accuracy_original_1, accuracy_perturbed_normal_1, accuracy_perturbed_max_1, accuracy_perturbed_weighted_1, accuracy_perturbed_mean_1, \
            yt_original_1, yt_perturbed_normal_1, yt_perturbed_max_1, yt_perturbed_weighted_1, yt_perturbed_mean_1, \
            pt_original_1, pt_perturbed_normal_1, pt_perturbed_max_1, pt_perturbed_weighted_1, pt_perturbed_mean_1 = experiment(dataloader, device, model, no_iterations=1, no_batches=1, eps=epsilon)

            print("no_iterations: 2")
            accuracy_original_2, accuracy_perturbed_normal_2, accuracy_perturbed_max_2, accuracy_perturbed_weighted_2, accuracy_perturbed_mean_2, \
            yt_original_2, yt_perturbed_normal_2, yt_perturbed_max_2, yt_perturbed_weighted_2, yt_perturbed_mean_2, \
            pt_original_2, pt_perturbed_normal_2, pt_perturbed_max_2, pt_perturbed_weighted_2, pt_perturbed_mean_2 = experiment(dataloader, device, model, no_iterations=2, no_batches=1, eps=epsilon)

            print("no_iterations: 10")
            accuracy_original_10, accuracy_perturbed_normal_10, accuracy_perturbed_max_10, accuracy_perturbed_weighted_10, accuracy_perturbed_mean_10, \
            yt_original_10, yt_perturbed_normal_10, yt_perturbed_max_10, yt_perturbed_weighted_10, yt_perturbed_mean_10, \
            pt_original_10, pt_perturbed_normal_10, pt_perturbed_max_10, pt_perturbed_weighted_10, pt_perturbed_mean_10 = experiment(dataloader, device, model, no_iterations=10, no_batches=1, eps=epsilon)

            print("---")

            print("Original accuracy, iter 1: ", accuracy_original_1)
            print("Perturbed accuracy normal, iter 1: ", accuracy_perturbed_normal_1)
            print("Perturbed accuracy max, iter 1: ", accuracy_perturbed_max_1)
            print("Perturbed accuracy weighted, iter 1: ", accuracy_perturbed_weighted_1)
            print("Perturbed accuracy mean, iter 1: ", accuracy_perturbed_mean_1)

            print("---")

            print("Original accuracy, iter 2: ", accuracy_original_2)
            print("Perturbed accuracy normal, iter 2: ", accuracy_perturbed_normal_2)
            print("Perturbed accuracy max, iter 2: ", accuracy_perturbed_max_2)
            print("Perturbed accuracy weighted, iter 2: ", accuracy_perturbed_weighted_2)
            print("Perturbed accuracy mean, iter 2: ", accuracy_perturbed_mean_2)

            print("---")

            print("Original accuracy, iter 10: ", accuracy_original_10)
            print("Perturbed accuracy normal, iter 10: ", accuracy_perturbed_normal_10)
            print("Perturbed accuracy max, iter 10: ", accuracy_perturbed_max_10)
            print("Perturbed accuracy weighted, iter 10: ", accuracy_perturbed_weighted_10)
            print("Perturbed accuracy mean, iter 10: ", accuracy_perturbed_mean_10)


            print("---")


            print("Original y_t, iter 1: ", yt_original_1)
            print("Perturbed y_t normal, iter 1: ", yt_perturbed_normal_1)
            print("Perturbed y_t max, iter 1: ", yt_perturbed_max_1)
            print("Perturbed y_t weighted, iter 1: ", yt_perturbed_weighted_1)
            print("Perturbed y_t mean, iter 1: ", yt_perturbed_mean_1)

            print("---")

            print("Original y_t, iter 2: ", yt_original_2)
            print("Perturbed y_t normal, iter 2: ", yt_perturbed_normal_2)
            print("Perturbed y_t max, iter 2: ", yt_perturbed_max_2)
            print("Perturbed y_t weighted, iter 2: ", yt_perturbed_weighted_2)
            print("Perturbed y_t mean, iter 2: ", yt_perturbed_mean_2)

            print("---")

            print("Original y_t, iter 10: ", yt_original_10)
            print("Perturbed y_t normal, iter 10: ", yt_perturbed_normal_10)
            print("Perturbed y_t max, iter 10: ", yt_perturbed_max_10)
            print("Perturbed y_t weighted, iter 10: ", yt_perturbed_weighted_10)
            print("Perturbed y_t mean, iter 10: ", yt_perturbed_mean_10)


            print("---")


            print("Original p_t, iter 1: ", pt_original_1)
            print("Perturbed p_t normal, iter 1: ", pt_perturbed_normal_1)
            print("Perturbed p_t max, iter 1: ", pt_perturbed_max_1)
            print("Perturbed p_t weighted, iter 1: ", pt_perturbed_weighted_1)
            print("Perturbed p_t mean, iter 1: ", pt_perturbed_mean_1)

            print("---")

            print("Original p_t, iter 2: ", pt_original_2)
            print("Perturbed p_t normal, iter 2: ", pt_perturbed_normal_2)
            print("Perturbed p_t max, iter 2: ", pt_perturbed_max_2)
            print("Perturbed p_t weighted, iter 2: ", pt_perturbed_weighted_2)
            print("Perturbed p_t mean, iter 2: ", pt_perturbed_mean_2)

            print("---")

            print("Original p_t, iter 10: ", pt_original_10)
            print("Perturbed p_t normal, iter 10: ", pt_perturbed_normal_10)
            print("Perturbed p_t max, iter 10: ", pt_perturbed_max_10)
            print("Perturbed p_t weighted, iter 10: ", pt_perturbed_weighted_10)
            print("Perturbed p_t mean, iter 10: ", pt_perturbed_mean_10)



            
            iter1y_t = [yt_perturbed_weighted_1-yt_original_1, yt_perturbed_normal_1-yt_original_1, yt_perturbed_mean_1-yt_original_1, yt_perturbed_max_1-yt_original_1]
            iter1p_t = [pt_perturbed_weighted_1-pt_original_1, pt_perturbed_normal_1-pt_original_1, pt_perturbed_mean_1-pt_original_1, pt_perturbed_max_1-pt_original_1]
            iter1acc_t = [accuracy_perturbed_weighted_1-accuracy_original_1, accuracy_perturbed_normal_1-accuracy_original_1, accuracy_perturbed_mean_1-accuracy_original_1, accuracy_perturbed_max_1-accuracy_original_1]
            iter2y_t = [yt_perturbed_weighted_2-yt_original_2, yt_perturbed_normal_2-yt_original_2, yt_perturbed_mean_2-yt_original_2, yt_perturbed_max_2-yt_original_2]
            iter2p_t = [pt_perturbed_weighted_2-pt_original_2, pt_perturbed_normal_2-pt_original_2, pt_perturbed_mean_2-pt_original_2, pt_perturbed_max_2-pt_original_2]
            iter2acc_t = [accuracy_perturbed_weighted_2-accuracy_original_2, accuracy_perturbed_normal_2-accuracy_original_2, accuracy_perturbed_mean_2-accuracy_original_2, accuracy_perturbed_max_2-accuracy_original_2]
            iter10y_t = [yt_perturbed_weighted_10-yt_original_10, yt_perturbed_normal_10-yt_original_10, yt_perturbed_mean_10-yt_original_10, yt_perturbed_max_10-yt_original_10]
            iter10p_t = [pt_perturbed_weighted_10-pt_original_10, pt_perturbed_normal_10-pt_original_10, pt_perturbed_mean_10-pt_original_10, pt_perturbed_max_10-pt_original_10]
            iter10acc_t = [accuracy_perturbed_weighted_10-accuracy_original_10, accuracy_perturbed_normal_10-accuracy_original_10, accuracy_perturbed_mean_10-accuracy_original_10, accuracy_perturbed_max_10-accuracy_original_10]

            plotFig3(iter1y_t, iter1p_t, iter1acc_t, iter2y_t, iter2p_t, iter2acc_t, iter10y_t, iter10p_t, iter10acc_t, "vgg16")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Initialization
# ----> 3 import torch
#       4 import torch.nn as nn
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'torch'
